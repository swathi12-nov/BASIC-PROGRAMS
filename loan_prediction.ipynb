# %% [markdown]
# <a href="https://colab.research.google.com/github/swathi12-nov/BASIC-PROGRAMS/blob/main/loan_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/content/loan_approval_dataset.csv")

# %%
df.head()

# %%
df.tail()
# Out:
#       loan_id   no_of_dependents      education  self_employed   income_annum  \
# 4264     4265                  5       Graduate            Yes        1000000
# 4265     4266                  0   Not Graduate            Yes        3300000
# 4266     4267                  2   Not Graduate             No        6500000
# 4267     4268                  1   Not Graduate             No        4100000
# 4268     4269                  1       Graduate             No        9200000
#
#        loan_amount   loan_term   cibil_score   residential_assets_value  \
# 4264       2300000          12           317                    2800000
# 4265      11300000          20           559                    4200000
# 4266      23900000          18           457                    1200000
# 4267      12800000           8           780                    8200000
# 4268      29700000          10           607                   17800000
#
# ...

# %%
df.isnull().sum()
# Out:
# loan_id                      0
#  no_of_dependents            0
#  education                   0
#  self_employed               0
#  income_annum                0
#  loan_amount                 0
#  loan_term                   0
#  cibil_score                 0
#  residential_assets_value    0
#  commercial_assets_value     0
#  luxury_assets_value         0
#  bank_asset_value            0
#  loan_status                 0
# dtype: int64

# %%
df.describe()
# Out:
#            loan_id   no_of_dependents   income_annum   loan_amount  \
# count  4269.000000        4269.000000   4.269000e+03  4.269000e+03
# mean   2135.000000           2.498712   5.059124e+06  1.513345e+07
# std    1232.498479           1.695910   2.806840e+06  9.043363e+06
# min       1.000000           0.000000   2.000000e+05  3.000000e+05
# 25%    1068.000000           1.000000   2.700000e+06  7.700000e+06
# 50%    2135.000000           3.000000   5.100000e+06  1.450000e+07
# 75%    3202.000000           4.000000   7.500000e+06  2.150000e+07
# max    4269.000000           5.000000   9.900000e+06  3.950000e+07
#
#          loan_term   cibil_score   residential_assets_value  \
# count  4269.000000   4269.000000               4.269000e+03
# mean     10.900445    599.936051               7.472617e+06
# std       5.709187    172.430401               6.503637e+06
# min       2.000000    300.000000              -1.000000e+05
# ...

# %%
df.shape
# Out:
# (4269, 13)

# %%
try:
    unique_education = df[" education"].unique()
    print(unique_education)

except KeyError:
    print("Error: The column 'education' does not exist in the DataFrame.")
except TypeError:
    print("Error: The 'education' column contains unhashable data types.")
# Out:
# [' Graduate' ' Not Graduate']

# %%
df[" education"].unique()
# Out:
# array([' Graduate', ' Not Graduate'], dtype=object)

# %%
# Check the actual column names in your DataFrame
print(df.columns)

# Assuming the correct column name is 'Education' (based on common capitalization)
# or any other name that you find from the output above, update your code to:
unique_education = df[" education"].unique()  # Replace 'Education' with the actual column name if different
print(unique_education)
# Out:
# Index(['loan_id', ' no_of_dependents', ' education', ' self_employed',
#        ' income_annum', ' loan_amount', ' loan_term', ' cibil_score',
#        ' residential_assets_value', ' commercial_assets_value',
#        ' luxury_assets_value', ' bank_asset_value', ' loan_status'],
#       dtype='object')
# [' Graduate' ' Not Graduate']

# %%
df[" education"].unique()
# Out:
# array([' Graduate', ' Not Graduate'], dtype=object)

# %%
df[" education"].value_counts()
# Out:
#  education
# Graduate        2144
# Not Graduate    2125
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
Label_Encoder = LabelEncoder()

# %%
print(Label_Encoder)
# Out:
# LabelEncoder()

# %%
df[" education"] = Label_Encoder.fit_transform(df[" education"])

# %%
df
# Out:
#       loan_id   no_of_dependents   education  self_employed   income_annum  \
# 0           1                  2           0             No        9600000
# 1           2                  0           1            Yes        4100000
# 2           3                  3           0             No        9100000
# 3           4                  3           0             No        8200000
# 4           5                  5           1            Yes        9800000
# ...       ...                ...         ...            ...            ...
# 4264     4265                  5           0            Yes        1000000
# 4265     4266                  0           1            Yes        3300000
# 4266     4267                  2           1             No        6500000
# 4267     4268                  1           1             No        4100000
# 4268     4269                  1           0             No        9200000
#
# ...

# %%
df[" self_employed"].unique()
# Out:
# array([' No', ' Yes'], dtype=object)

# %%
df[" self_employed"] = Label_Encoder.fit_transform(df[" self_employed"])

# %%
df[" loan_status"].unique()
# Out:
# array([' Approved', ' Rejected'], dtype=object)

# %%
df[" loan_status"] = Label_Encoder.fit_transform(df[" loan_status"])

# %%
df.head()
# Out:
#    loan_id   no_of_dependents   education   self_employed   income_annum  \
# 0        1                  2           0               0        9600000
# 1        2                  0           1               1        4100000
# 2        3                  3           0               0        9100000
# 3        4                  3           0               0        8200000
# 4        5                  5           1               1        9800000
#
#     loan_amount   loan_term   cibil_score   residential_assets_value  \
# 0      29900000          12           778                    2400000
# 1      12200000           8           417                    2700000
# 2      29700000          20           506                    7100000
# 3      30700000           8           467                   18200000
# 4      24200000          20           382                   12400000
#
#     commercial_assets_value   luxury_assets_value   bank_asset_value  \
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
X = df.drop(columns=' loan_status', axis = 1)
Y = df[' loan_status']

# %%
print(X)
# Out:
#       loan_id   no_of_dependents   education   self_employed   income_annum  \
# 0           1                  2           0               0        9600000
# 1           2                  0           1               1        4100000
# 2           3                  3           0               0        9100000
# 3           4                  3           0               0        8200000
# 4           5                  5           1               1        9800000
# ...       ...                ...         ...             ...            ...
# 4264     4265                  5           0               1        1000000
# 4265     4266                  0           1               1        3300000
# 4266     4267                  2           1               0        6500000
# 4267     4268                  1           1               0        4100000
# 4268     4269                  1           0               0        9200000
#
# ...

# %%
print(Y)
# Out:
# 0       0
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 4264    1
# 4265    0
# 4266    1
# 4267    0
# 4268    0
# Name:  loan_status, Length: 4269, dtype: int64

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size = 0.2,stratify = Y,random_state = 2)

# %%
print(X.shape,X_train.shape,X_test.shape )
# Out:
# (4269, 12) (3415, 12) (854, 12)

# %%
model = LogisticRegression()

# %%
model.fit(X_train,Y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction,Y_test)
print(test_data_accuracy)
# Out:
# 0.7775175644028103

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
rf = RandomForestClassifier(n_estimators=100)  # You can adjust n_estimators as needed
rf.fit(X_train,Y_train)
# Out:
# RandomForestClassifier()

# %%
X_test_prediction = rf.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction,Y_test)
print(test_data_accuracy)
# Out:
# 0.9789227166276346

# %%
import joblib

joblib.dump(model, '/content/loan_approval_dataset.csv')
# Load it later with:
# model = joblib.load('random_forest_model.pkl')
# Out:
# ['/content/loan_approval_dataset.csv']

# %%
y_pred = model.predict(X_test)

# %%
new_data = [[1,2,0,0,9600000,29900000,12,778,2400000,17600000,22700000,8000000]]  # Example input
prediction = model.predict(new_data)
print("Prediction:", prediction)
if prediction == 1:
  print("Loan Approved")
else:
  print("Loan Not Approved")
# Out:
# Prediction: [0]
# Loan Not Approved
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
